# %% [markdown]
# **<div class="markdown-google-sans">
#
# ## **Complex YOLOv4 3d Object detection**
# </div>
# This notebook is used to detect cars .
# Comlpex Yolov4 used for 3D object detection to detect cars using pretrained model, trained on kitti dataset
#
# ---
#
# **Kitti Dataset** https://www.cvlibs.net/datasets/kitti/eval_object.php?obj_benchmark=3d
# - 7481 training images and 7518 validation images as well as the corresponding lidar point clouds and camera calibration parameters

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Requirement**
# </div>

# %%
pip install mayavi pyside2
# !pip uninstall opencv-python-headless -y 
# !pip install opencv-python --upgrade
pip install -U -r requirements.txt

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **How to run**
# </div>

# %%
cd src/data_process

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **install weights then put it in data_process directory**
#
# * weights --> complex_yolov4_mse_loss.pth https://drive.google.com/drive/folders/1RHD9PBvk-9SjbKwoi_Q1kl9-UGFo2Pth
# </div>

# %%
# !python src/test.py --gpu_idx 0 --pretrained_path src/data_process/complex_yolov4_mse_loss.pth --cfgfile ../config/cfg/complex_yolov4.cfg
